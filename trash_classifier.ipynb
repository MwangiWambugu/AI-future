# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import tensorflow as tf
import os

# %%
img_height, img_width = 224, 224
batch_size = 32
dataset_dir = "/content/drive/MyDrive/dataset-resized"
labels_map = {
    "cardboard": 0,
    "glass": 1,
    "metal": 2,
    "paper": 3,
    "plastic": 4,
    "trash": 5
}

# %%
# Load dataset assuming subfolder structure: /class_name/image.jpg
train_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    label_mode='int',
    validation_split=0.2,
    subset="training",
    seed=123
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    dataset_dir,
    image_size=(img_height, img_width),
    batch_size=batch_size,
    label_mode='int',
    validation_split=0.2,
    subset="validation",
    seed=123
)
# Out:
# Found 2527 files belonging to 6 classes.
# Using 2022 files for training.
# Found 2527 files belonging to 6 classes.
# Using 505 files for validation.

# %%
# Normalize images
normalization_layer = tf.keras.layers.Rescaling(1./255)
train_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
val_ds = val_ds.map(lambda x, y: (normalization_layer(x), y))

# %%
# Build model using MobileNetV2
base_model = tf.keras.applications.MobileNetV2(input_shape=(224, 224, 3),
                                               include_top=False,
                                               weights='imagenet')
base_model.trainable = False

model = tf.keras.Sequential([
    base_model,
    tf.keras.layers.GlobalAveragePooling2D(),
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax')
])

model.compile(optimizer='adam',
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

model.fit(train_ds, validation_data=val_ds, epochs=5)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet_v2/mobilenet_v2_weights_tf_dim_ordering_tf_kernels_1.0_224_no_top.h5
# 9406464/9406464 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# Epoch 1/5
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 705s 11s/step - accuracy: 0.5699 - loss: 1.0986 - val_accuracy: 0.8079 - val_loss: 0.5440
# Epoch 2/5
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.8400 - loss: 0.4599 - val_accuracy: 0.7683 - val_loss: 0.5812
# Epoch 3/5
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 10s 128ms/step - accuracy: 0.8923 - loss: 0.3223 - val_accuracy: 0.8574 - val_loss: 0.4465
# Epoch 4/5
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 9s 111ms/step - accuracy: 0.9449 - loss: 0.2065 - val_accuracy: 0.8238 - val_loss: 0.5056
# Epoch 5/5
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 8s 129ms/step - accuracy: 0.9584 - loss: 0.1579 - val_accuracy: 0.8396 - val_loss: 0.4799

# %%
# Convert to TensorFlow Lite
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()

# Save the TFLite model
with open('recyclable_classifier.tflite', 'wb') as f:
    f.write(tflite_model)

print("TFLite model created and saved successfully.")
# Out:
# Saved artifact at '/tmp/tmpzi526p42'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_154')
# Output Type:
#   TensorSpec(shape=(None, 6), dtype=tf.float32, name=None)
# Captures:
#   133436922998864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133436922999056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870490256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433877926480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133436922999632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870490640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870492176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870491792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133436922999440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870492368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870491408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870494288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870492560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870493328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870491600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870495440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870497744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870496400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870496784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870494672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870499280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870498512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871286352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870498896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433870496976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871288080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871288464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871288848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871288656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871287312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871290000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871290384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871290768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871290576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871286736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871291920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871292304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871292688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871292496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871287696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871289616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871294416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871294800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871294608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871291152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871293456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871296528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871296912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871296720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871293840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871298064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871298448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871298832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871298640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871295568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871299984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871300368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871300752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871300560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871296144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871301904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871302480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871301136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871302288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433871299600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853837584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853838928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853839312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853839120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853837776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853840464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853840848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853841232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853841040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853838352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853842384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853842768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853843152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853842960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853838544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853844304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853844688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853845072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853844880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853840080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853846224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853846608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853846992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853846800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853842000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853848144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853848528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853848912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853848720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853843920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853850064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853850448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853850832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853850640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853845840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853851984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853852368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853852752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853852560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853847760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853851216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854231184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854230608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853853520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433853849680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854232720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854233104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854233488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854233296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854230800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854234640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854235024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854235408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854235216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854231376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854236560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854236944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854237328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854237136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854232336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854238480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854238864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854239248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854239056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854234256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854240400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854240784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854241168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854240976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854236176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854242320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854242704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854243088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854242896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854238096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854244240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854244624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854245008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854244816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854240016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854246160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854246736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854245392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854246544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433854243856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835749648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835750992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835751376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835751184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835749840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835752528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835752912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835753296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835753104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835750416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835754448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835754832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835755216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835755024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835750608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835756368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835756752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835757136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835756944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835752144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835758288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835758672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835759056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835758864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835754064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835760208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835760592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835760976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835760784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835755984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835762128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835762512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835762896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835762704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835757904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835764048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835764432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835764816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835764624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835759824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835763280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836110096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836110864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835765584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433835761744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836112016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836112400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836112784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836112592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836110672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836113936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836114320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836114704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836114512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836109904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836115856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836116240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836116624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836116432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836111632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836117776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836119696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836118928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836118352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836113552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836121424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836119312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836120848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836118544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836115472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836121616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836122000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836122384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836122192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836118160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836123536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836123920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836124304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836124112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836117392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836125456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836126032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836124688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836125840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836123152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836552464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836553808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836554192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836554000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836553424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836555344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836555728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836556112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836555920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836552656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836557264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836557648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836558032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836557840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836552848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836559184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836559568: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836559952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836559760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836554960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836561104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836561488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836561872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836561680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836556880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836560336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836564176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836563600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   133433836564944: TensorSpec(shape=(), dtype=tf.resource, name=None)
# TFLite model created and saved successfully.

# %%
import numpy as np
from tensorflow.keras.preprocessing import image

# Load one test image (update path as needed)
test_img_path = "/content/drive/MyDrive/dataset-resized/glass/glass50.jpg"
img = image.load_img(test_img_path, target_size=(224, 224))
img_array = image.img_to_array(img) / 255.0
input_data = np.expand_dims(img_array, axis=0).astype(np.float32)

# Load TFLite model
interpreter = tf.lite.Interpreter(model_path="recyclable_classifier.tflite")
interpreter.allocate_tensors()

input_index = interpreter.get_input_details()[0]["index"]
output_index = interpreter.get_output_details()[0]["index"]

# Run inference
interpreter.set_tensor(input_index, input_data)
interpreter.invoke()
output = interpreter.get_tensor(output_index)

predicted_class = np.argmax(output)
print("Predicted class index:", predicted_class)
# Out:
# Predicted class index: 1
